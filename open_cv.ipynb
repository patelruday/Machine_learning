# %% [markdown]
# <a href="https://colab.research.google.com/github/patelruday/Machine_learning/blob/main/open_cv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
print(cv2.__version__)
# Out:
# 4.8.0

# %%
img=cv2.imread('gan_3.JPEG',1)

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (275, 183, 3)

# %%
# cv2 uses BGR format while matplotlib use RGB, so covert BGR to RGB

# %%
RGB_img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(RGB_img)

# %%
os.chdir(directory)

# %%
directory=r'E:\AI_CDAC'

# %%
os.listdir(directory)
# Out:
# ['lab_work',
#  'lab_work2',
#  'module_1',
#  'module_2',
#  'module_2_uday',
#  'module_2_uday.rar']

# %%
cv2.imwrite('ganeshji.jpeg',img)
# Out:
# True

# %%
os.listdir(directory)
# Out:
# ['ganeshji.jpeg',
#  'lab_work',
#  'lab_work2',
#  'module_1',
#  'module_2',
#  'module_2_uday',
#  'module_2_uday.rar']
